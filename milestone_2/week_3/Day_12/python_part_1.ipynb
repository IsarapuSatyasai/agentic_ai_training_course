# %%
# Variables & Types
name = 'satyasai' # String
'''
Defining multi-line comments
    line one
    line two
    line three
'''

age = 25 # Integer
height = 5.9 # float
is_student = True # boolean

# print(age)
print(name)
# Out:
# satyasai

# %%
# Control Flow
age = 10
if age >= 18:
  print("You are an Adult!")
elif age >= 13:
  print("You are a Teen!")
else:
  print("You are a child!")
# Out:
# You are a child!

# %%
# Loop
# age = 25
# while age > 20:
#   print("While loop running!")
#   age -= 1
#   if age == 22:
#     # break
#     continue

for i in range(10,1,-1):
  print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
# Example 1: Simple Grading
# marks = 91

# if marks >= 90:
#   print('Grade A')
# elif marks >= 70:
#   print('Grade B')
# else:
#   print('Grade C')

# Example 2: Loop
for num in range(1, 6):
  print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# string
name = 'satyasai' # String Variable
# print(type(name))
name = name.capitalize()
# name

# Slice Operation
# name[0:5]
# name[5:0:-1]
name = 'aytas'
# name[::-1]
name[-1]
# Out:
# 's'

# %%
# List
list = [1,2,3,4,5,'a']
# print(type(list[4]))

# for i in list:
#   print(i)
lst  = [23, 1,-1, 99, 10]
# lst.index(99)
# lst.index(-1)
lst[2] = 2
lst
# Out:
# [23, 1, 2, 99, 10]

# %%
# Tuples
# tuple = () # Empty tuple
t = ('a', 'b', 'c')
t[0] = 'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1066/2560357028.py in <cell line: 0>()
#       2 # tuple = () # Empty tuple
#       3 t = ('a', 'b', 'c')
# ----> 4 t[0] = 'd'
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Dictionary
d = {}
name = 'satya sai'
email = 'esarapusatya@example.com'
# New key-value pair
d['name'] = 'satya sai'
d['email'] = 'esarapusatya@example.com'
dt = {'name':'rajesh', 'email': 'rajesh@example.com', 'age':25}
# dt
for k,v in dt.items():
  print(k,v)
# Out:
# name rajesh
# email rajesh@example.com
# age 25

# %%
# Sets
s = set()
s = set([1,2,2,3])
s1 = set([1,2,3])
s2 = set([1,4,5])
# s2-s1
# s1.intersection(s2)
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5}

# %%
# List Comprehensions
lst = []
for i in range(1,10):
  # print(i)
  lst.append(i)

# lst

lst = [i for i in range(1,10)]
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
## F-String

name = 'satya'
age = 28

temp = f'Hi! My name is {name}, and my age is {age}.'
print(temp)
# Out:
# Hi! My name is satya, and my age is 28.

# %%
# 1. Calculate string length.

# Write a Python program to calculate the length of a string.

a = 'Google Colab'
len(a)
# Out:
# 12
